# %%
import sympy as sp
import numpy as np

s =sp.symbols("s")

# The explicit values for the stability fnction, used in the propositoin
alpha = sp.Rational("-0.17949873")
c = sp.Rational("0.42437056")
beta = sp.Rational("0.82050127")

# The value of the single root of K(s) in the proof of Prop 4.8
h = (c-np.abs(alpha))/(2*c*np.abs(alpha))
h_decimal = sp.N(h,12)
print(h_decimal)

# Numerator of K(s) for s = 1, this is greater than zero, therefore by the single root it is ngeative for s>\hat{s}
h1 = c-np.abs(alpha) - 2*c*np.abs(alpha)
h1_decimal = sp.N(h1,12)
print(h1_decimal)

# root of 4|alpha|c - d + 2|alpha|cs is smaller than 0
h2 = (c-np.abs(alpha))/(2*c*np.abs(alpha)) - 2
h2_decimal = sp.N(h2,12)
print(h2_decimal)

#4|alpha|c - d + 2|alpha|cs, for s = 1 is greater than 0.
h3 = 4*np.abs(alpha)*c - (c-np.abs(alpha))+ 2* np.abs(alpha)*c
h3_decimal = sp.N(h3,12)
print(h3_decimal)

s = sp.symbols("s")
W = 1/(1 + s + (15/32)*s**2 + (35/256)*s**3)
W1 = (1 + s + (15/32)*s**2 + (35/256)*s**3)

# This is the Last step in the proof, where it was stated that SymPy was used to expand the expression
h5 = sp.expand(W1 * (2*np.abs(alpha) +np.abs(alpha)*s - 2*s*np.abs(alpha)**2 + c*s) - np.abs(alpha)*(2 +(1+ 2*alpha)*s +c*s**2)*(1+s) - (1 + (alpha +1)*s + c*s**2)*s*c)
h5_decimal = sp.N(h5,12)
print(sp.latex(h5_decimal))
# Out:
# 1.60731946150
# 0.0925238768612
# -0.392680538498
# 0.212172029416
# 0.0737501545507 s^{4} + 0.0456750079656 s^{3} + 0.168280059375 s^{2}
